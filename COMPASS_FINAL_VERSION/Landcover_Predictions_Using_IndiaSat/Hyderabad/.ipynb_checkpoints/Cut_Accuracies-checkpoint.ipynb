# %%
import os, sys
import imageio
import numpy as np

greenery=1
water=2
BU=3
Bareland=4


main_folder="out_cutfiles/Hyderabad_median_2018_BU"
main_pixel_color_code=BU


main_pixel_count=0
total_relevant_pixel_count=0
empty_pics=0
green_count=0
water_count=0
BU_count=0
Bareland_count=0

for infile in os.listdir(main_folder):
    if infile[-4:]==".tif":
        print(infile)
        cut_Image=imageio.imread(main_folder+"/"+infile)
        print(np.unique(cut_Image,return_counts=True))
        if(main_pixel_color_code in np.unique(cut_Image,return_counts=True)[0]):
            print(np.where(np.unique(cut_Image,return_counts=True)[0]==main_pixel_color_code)[0][0])
            print(np.unique(cut_Image,return_counts=True)[1][np.where(np.unique(cut_Image,return_counts=True)[0]==main_pixel_color_code)[0][0]])
            main_pixel_count+=np.unique(cut_Image,return_counts=True)[1][np.where(np.unique(cut_Image,return_counts=True)[0]==main_pixel_color_code)[0][0]]
            total_relevant_pixel_count+=sum(np.unique(cut_Image,return_counts=True)[1])-np.unique(cut_Image,return_counts=True)[1][0]
    #         print(main_pixel_color_code,total_relevant_pixel_count,empty_pics)
        else:
            empty_pics+=1
            total_relevant_pixel_count+=sum(np.unique(cut_Image,return_counts=True)[1])-np.unique(cut_Image,return_counts=True)[1][0]
            
        if(greenery in np.unique(cut_Image,return_counts=True)[0]):
            green_count+=np.unique(cut_Image,return_counts=True)[1][np.where(np.unique(cut_Image,return_counts=True)[0]==greenery)[0][0]]
        if(water in np.unique(cut_Image,return_counts=True)[0]):
            water_count+=np.unique(cut_Image,return_counts=True)[1][np.where(np.unique(cut_Image,return_counts=True)[0]==water)[0][0]]
        if(BU in np.unique(cut_Image,return_counts=True)[0]):
            BU_count+=np.unique(cut_Image,return_counts=True)[1][np.where(np.unique(cut_Image,return_counts=True)[0]==BU)[0][0]]
        if(Bareland in np.unique(cut_Image,return_counts=True)[0]):
            Bareland_count+=np.unique(cut_Image,return_counts=True)[1][np.where(np.unique(cut_Image,return_counts=True)[0]==Bareland)[0][0]]
print(main_pixel_count,total_relevant_pixel_count,empty_pics)
print(green_count,water_count,BU_count,Bareland_count)
f=open(main_folder+"/result.txt","w+")
f.write(str(main_pixel_count)+","+str(total_relevant_pixel_count)+","+str(empty_pics))
f.write("\n\nGreenery= "+str(green_count)+"\nWater= "+str(water_count)+"\nBU= "+str(BU_count)+"\nBareland= "+str(Bareland_count))
f.close()
# Out:
# Hyderabad_2018_year_median@BU10.tif
# (Array([0, 3], dtype=int32), array([67, 98]))
# Hyderabad_2018_year_median@BU49.tif
# (Array([0, 3], dtype=int32), array([16,  9]))
# Hyderabad_2018_year_median@BU39.tif
# (Array([0, 3], dtype=int32), array([10,  5]))
# Hyderabad_2018_year_median@BU55.tif
# (Array([0, 3], dtype=int32), array([28, 21]))
# Hyderabad_2018_year_median@BU29.tif
# (Array([0, 3], dtype=int32), array([6, 6]))
# Hyderabad_2018_year_median@BU38.tif
# (Array([0, 3], dtype=int32), array([18, 12]))
# Hyderabad_2018_year_median@BU43.tif
# (Array([0, 3], dtype=int32), array([13,  3]))
# Hyderabad_2018_year_median@BU53.tif
# (Array([0, 3], dtype=int32), array([ 8, 12]))
# Hyderabad_2018_year_median@BU33.tif
# (Array([0, 3], dtype=int32), array([13, 29]))
# Hyderabad_2018_year_median@BU4.tif
# (Array([0, 3], dtype=int32), array([56, 61]))
# Hyderabad_2018_year_median@BU12.tif
# (Array([0, 3], dtype=int32), array([156, 132]))
# Hyderabad_2018_year_median@BU16.tif
# (Array([0, 3], dtype=int32), array([21, 19]))
# Hyderabad_2018_year_median@BU17.tif
# (Array([0, 3], dtype=int32), array([27, 37]))
# Hyderabad_2018_year_median@BU28.tif
# (Array([0, 3], dtype=int32), array([ 6, 10]))
# Hyderabad_2018_year_median@BU7.tif
# (Array([0, 3], dtype=int32), array([31, 25]))
# Hyderabad_2018_year_median@BU8.tif
# (Array([0, 3], dtype=int32), array([22, 10]))
# Hyderabad_2018_year_median@BU54.tif
# (Array([0, 3], dtype=int32), array([13,  7]))
# Hyderabad_2018_year_median@BU13.tif
# (Array([0, 3], dtype=int32), array([146, 184]))
# Hyderabad_2018_year_median@BU6.tif
# (Array([0, 3], dtype=int32), array([22, 18]))
# Hyderabad_2018_year_median@BU19.tif
# (Array([0, 3], dtype=int32), array([35, 35]))
# Hyderabad_2018_year_median@BU46.tif
# (Array([0, 3], dtype=int32), array([17,  8]))
# Hyderabad_2018_year_median@BU3.tif
# (Array([0, 3], dtype=int32), array([56, 88]))
# Hyderabad_2018_year_median@BU37.tif
# (Array([0, 3], dtype=int32), array([ 9, 11]))
# Hyderabad_2018_year_median@BU40.tif
# (Array([0, 3], dtype=int32), array([17, 13]))
# Hyderabad_2018_year_median@BU34.tif
# (Array([0, 3], dtype=int32), array([7, 5]))
# Hyderabad_2018_year_median@BU23.tif
# (Array([0, 3], dtype=int32), array([23, 19]))
# Hyderabad_2018_year_median@BU2.tif
# (Array([0, 3], dtype=int32), array([27,  8]))
# Hyderabad_2018_year_median@BU27.tif
# (Array([0, 3], dtype=int32), array([10, 25]))
# Hyderabad_2018_year_median@BU5.tif
# (Array([0, 3], dtype=int32), array([131, 157]))
# Hyderabad_2018_year_median@BU15.tif
# (Array([0, 3], dtype=int32), array([12, 30]))
# Hyderabad_2018_year_median@BU18.tif
# (Array([0, 3], dtype=int32), array([29, 70]))
# Hyderabad_2018_year_median@BU42.tif
# (Array([0, 3], dtype=int32), array([13,  7]))
# Hyderabad_2018_year_median@BU51.tif
# (Array([0, 3], dtype=int32), array([10, 14]))
# Hyderabad_2018_year_median@BU9.tif
# (Array([0, 3], dtype=int32), array([149, 426]))
# Hyderabad_2018_year_median@BU47.tif
# (Array([0, 3], dtype=int32), array([12,  8]))
# Hyderabad_2018_year_median@BU26.tif
# (Array([0, 3], dtype=int32), array([13, 23]))
# Hyderabad_2018_year_median@BU35.tif
# (Array([0, 3], dtype=int32), array([11,  9]))
# Hyderabad_2018_year_median@BU32.tif
# (Array([0, 3], dtype=int32), array([12, 18]))
# Hyderabad_2018_year_median@BU52.tif
# (Array([0, 3], dtype=int32), array([9, 7]))
# Hyderabad_2018_year_median@BU1.tif
# (Array([0, 3], dtype=int32), array([7, 2]))
# Hyderabad_2018_year_median@BU44.tif
# (Array([0, 3], dtype=int32), array([19, 17]))
# Hyderabad_2018_year_median@BU45.tif
# (Array([0, 3], dtype=int32), array([15, 13]))
# Hyderabad_2018_year_median@BU11.tif
# (Array([0, 3], dtype=int32), array([ 76, 162]))
# Hyderabad_2018_year_median@BU31.tif
# (Array([0, 3], dtype=int32), array([17, 19]))
# Hyderabad_2018_year_median@BU36.tif
# (Array([0, 3], dtype=int32), array([15, 15]))
# Hyderabad_2018_year_median@BU20.tif
# (Array([0, 3], dtype=int32), array([ 57, 112]))
# Hyderabad_2018_year_median@BU48.tif
# (Array([0, 3], dtype=int32), array([13,  7]))
# Hyderabad_2018_year_median@BU25.tif
# (Array([0, 3], dtype=int32), array([12, 18]))
# Hyderabad_2018_year_median@BU24.tif
# (Array([0, 3], dtype=int32), array([13,  7]))
# Hyderabad_2018_year_median@BU41.tif
# (Array([0, 3], dtype=int32), array([25, 31]))
# Hyderabad_2018_year_median@BU50.tif
# (Array([0, 3], dtype=int32), array([11,  9]))
# Hyderabad_2018_year_median@BU14.tif
# (Array([0, 3], dtype=int32), array([24, 46]))
# Hyderabad_2018_year_median@BU22.tif
# (Array([0, 3], dtype=int32), array([19, 23]))
# Hyderabad_2018_year_median@BU21.tif
# (Array([0, 3], dtype=int32), array([18, 30]))
# Hyderabad_2018_year_median@BU30.tif
# (Array([0, 3], dtype=int32), array([11, 19]))
# 0 2209 55
# 0 0 2209 0
